# %% [markdown]
# # Movie Recommendation System using Python

# %% [markdown]
# ### Introduction

# %% [markdown]
# Everyone in this world definitely likes movies, such as fantasy, horror, crime, romance, thriller, comedy, drama, action and other genre films, and everyone must have an interest in one or many of these genres. for that, disney+ is here to present movie shows from various types of genres, therefore I created a movie recommendation system based on the user search title using data from disney+

# %% [markdown]
# ### What is Recommendation System??

# %% [markdown]
# In simple terms, a recommendation system is a filtering program with the primary purpose of predicting a user's "rating" or "wish" for a domain-specific item or items. Since the domain-specific object in our project is movies, the main purpose of our recommendation system is to filter and anticipate only the movies that the user likes based on some information from the user.

# %% [markdown]
# ## Importing Relevant Python Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import difflib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## Data Collection

# %% [markdown]
# read the dataset

# %%
dataset = pd.read_csv('disney_plus_projects.csv')

# %% [markdown]
# ## Data Pre-Processing

# %%
#add index column
dataset['index'] = dataset.index

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7850 entries, 0 to 7849
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          7850 non-null   object
#  1   year           7703 non-null   object
#  2   certificate    7850 non-null   object
#  3   runtime_min    7850 non-null   int64
#  4   genre          7850 non-null   object
#  5   rating         7850 non-null   float64
#  6   votes          7850 non-null   int64
#  7   director_star  7850 non-null   object
#  8   index          7850 non-null   int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 552.1+ KB

# %%
dataset.head(5)
# Out:
#               title       year certificate  runtime_min  \
# 0    The King's Man       2021           R          131
# 1   West Side Story       2021       PG-13          156
# 2  The Walking Dead  2010–2022       TV-14           44
# 3          Free Guy       2021       PG-13          115
# 4       Pam & Tommy       2022       TV-MA          340
#
#                                      genre  rating   votes     director_star  \
# 0  Action, Adventure, Thriller                 6.4   90344    Matthew Vaughn
# 1        Crime, Drama, Musical                 7.5   46778  Steven Spielberg
# 2      Drama, Horror, Thriller                 8.3  934972    Andrew Lincoln
# 3    Action, Adventure, Comedy                 7.2  303127        Shawn Levy
# 4    Biography, Drama, Romance                 7.4   16576        Lily James
#
#    index
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4

# %%
dataset.duplicated().sum()
# Out:
# 0

# %%
dataset.isnull().sum()
# Out:
# title              0
# year             147
# certificate        0
# runtime_min        0
# genre              0
# rating             0
# votes              0
# director_star      0
# index              0
# dtype: int64

# %%
#filling missing value
dataset.fillna('NULL', inplace= True)

# %%
#make sure  no one missing value
dataset.isnull().sum()
# Out:
# title            0
# year             0
# certificate      0
# runtime_min      0
# genre            0
# rating           0
# votes            0
# director_star    0
# index            0
# dtype: int64

# %%
dataset.shape
# Out:
# (7850, 9)

# %%
# selecting relevant features for machine learning model
selected_features = {"title", "year", "genre", "director_star", "certificate"}

# %%
#combine all selected features
combined_features = dataset["year"]+ " "+dataset["title"]+ " "+dataset["genre"]+ " "+dataset["certificate"]+ " "+dataset["director_star"]

# %%
print(combined_features)
# Out:
# 0       2021 The King's Man Action, Adventure, Thrille...
# 1       2021 West Side Story Crime, Drama, Musical    ...
# 2       2010–2022 The Walking Dead Drama, Horror, Thri...
# 3       2021 Free Guy Action, Adventure, Comedy       ...
# 4       2022 Pam & Tommy Biography, Drama, Romance    ...
#                               ...
# 7845    2020 Rapunzel's Tangled Adventure Animation, A...
# 7846    2020–2021 Rapunzel's Tangled Adventure Animati...
# 7847    2020 Miraculous: Tales of Ladybug & Cat Noir A...
# 7848    2020–2021 Miraculous: Tales of Ladybug & Cat N...
# 7849    2020 Star Wars Resistance Animation, Action, A...
# Length: 7850, dtype: object

# %%
#convert data text to vectors
vectorizer = TfidfVectorizer()
feature_vektor = vectorizer.fit_transform(combined_features)
print(feature_vektor)
# Out:
#   (0, 5068)	0.5768749217258283
#   (0, 3159)	0.37294797150216497
#   (0, 4845)	0.32420182095969047
#   (0, 166)	0.1431577112058066
#   (0, 150)	0.15214990192207364
#   (0, 3089)	0.3501285996686016
#   (0, 2735)	0.43642591857046065
#   (0, 4821)	0.1344833941749473
#   (0, 100)	0.2196160048250088
#   (1, 4567)	0.43546556857210605
#   (1, 4633)	0.3294448304345145
#   (1, 6)	0.23668408713835454
#   (1, 3776)	0.10119114199122675
#   (1, 3424)	0.2695857441199328
#   (1, 1490)	0.11411902364357454
#   (1, 1196)	0.23205672128505192
#   (1, 4654)	0.3162743033130422
#   (1, 4450)	0.45537203932480463
#   (1, 5192)	0.40143523204941056
#   (1, 100)	0.16578153219513578
#   (2, 2950)	0.46507649275929935
#   (2, 291)	0.3364656436160334
#   (2, 7)	0.15422347551790247
#   (2, 4992)	0.060332955168988234
#   (2, 2357)	0.302683740394361
#   :	:
#   (7848, 1199)	0.3783468261198294
#   (7848, 3525)	0.3129005930996809
#   (7848, 938)	0.3102467856295407
#   (7848, 2819)	0.3129005930996809
#   (7848, 4760)	0.30833531443749657
#   (7848, 3318)	0.3129005930996809
#   (7848, 1291)	0.18536145347367827
#   (7848, 99)	0.18962157015980818
#   (7848, 3576)	0.198173344541576
#   (7848, 313)	0.1113057484571666
#   (7848, 3520)	0.18493857899058075
#   (7848, 166)	0.12410643677330414
#   (7848, 150)	0.13190195640813207
#   (7848, 100)	0.1903897428063595
#   (7849, 4099)	0.4286302555318844
#   (7849, 4067)	0.46390595643266197
#   (7849, 2627)	0.4143197291733628
#   (7849, 1291)	0.2398923005007276
#   (7849, 5144)	0.3095063012840358
#   (7849, 4602)	0.2878633748095431
#   (7849, 99)	0.24540568622945122
#   (7849, 313)	0.14405040290718624
#   (7849, 3520)	0.23934502203116312
#   (7849, 166)	0.16061688159304244
#   (7849, 150)	0.17070573827684601

# %% [markdown]
# ## Cosine Similarity

# %%
similarity = cosine_similarity(feature_vektor)
print(similarity)
# Out:
# [[1.         0.03640828 0.09497621 ... 0.04207617 0.0796483  0.04896641]
#  [0.03640828 1.         0.01330069 ... 0.         0.0315631  0.        ]
#  [0.09497621 0.01330069 1.         ... 0.00455191 0.         0.        ]
#  ...
#  [0.04207617 0.         0.00455191 ... 1.         0.67332104 0.11678795]
#  [0.0796483  0.0315631  0.         ... 0.67332104 1.         0.19374877]
#  [0.04896641 0.         0.         ... 0.11678795 0.19374877 1.        ]]

# %%
similarity.shape
# Out:
# (7850, 7850)

# %%
#find movie name from user input
movie_name = input("disney movie apa yang ingin kamu tonton : ")
# Out:
# disney movie apa yang ingin kamu tonton : Avengers: Endgame

# %%
#make a list of movies from the dataset
list_of_all_titles = dataset["title"].tolist()
print(list_of_all_titles)
# Out:
# ["The King's Man", 'West Side Story', 'The Walking Dead', 'Free Guy', 'Pam & Tommy', 'No Exit', 'Fresh', 'Encanto', 'Death on the Nile', 'The Dropout', 'The French Dispatch', 'Morbius', 'The Book of Boba Fett', "Grey's Anatomy", 'Eternals', 'Moon Knight', 'This Is Us', 'Criminal Minds', "It's Always Sunny in Philadelphia", 'The Mandalorian', 'Dopesick', 'Castle', 'The Last Duel', 'How I Met Your Father', 'Turning Red', 'Modern Family', 'Big Sky', 'Daredevil', 'Avengers: Endgame', 'How I Met Your Mother', 'American Horror Story', 'Lost', 'The Simpsons', 'Bones', 'Family Guy', 'Snowfall', 'The Proud Family: Louder and Prouder', 'New Girl', 'Shang-Chi and the Legend of the Ten Rings', '9-1-1: Lone Star', 'Sons of Anarchy', 'Better Things', 'M*A*S*H', 'Abbott Elementary', 'Venom: Let There Be Carnage', 'Hawkeye', 'Antlers', 'Dollface', 'Star Wars: The Clone Wars', "Bob's Burgers", '9-1-1', 'Buffy the Vampire Slayer', 'The Resident', 'Homeland', 'Avengers: Infinity War', 'Only Murders in the Building', 'The Punisher', 'Arrested Development', 'Fight Club', 'Spider-Man', 'Station 19', 'Obi-Wan Kenobi', 'Scrubs', 'Titanic', 'Deadpool', 'Agents of S.H.I.E.L.D.', 'Law & Order: Organized Crime', 'Spider-Man: Homecoming', 'What We Do in the Shadows', 'Futurama', 'Black Widow', 'Once Upon a Time', 'Loki', 'Deadpool 2', 'The Americans', 'Prison Break', 'Gone Girl', 'Cruella', 'WandaVision', 'The Golden Girls', 'Avatar', 'Spider-Man: Into the Spider-Verse', 'Paddington', '24', 'Atlanta', 'Star Wars', 'MASH', 'Guardians of the Galaxy', 'The Prestige', 'What If...?', 'Spider-Man: Far from Home', 'Firefly', 'Raya and the Last Dragon', 'Venom', 'Thor: Ragnarok', 'Jungle Cruise', 'Hamilton', 'The Princess Bride', 'Pirates of the Caribbean: The Curse of the Black Pearl', 'The Orville', 'The Amazing Spider-Man', 'Jojo Rabbit', 'Black Panther', 'Star Wars: Episode IX - The Rise of Skywalker', 'Jessica Jones', 'Moana', 'The Greatest Showman', 'Little Miss Sunshine', 'Luca', 'Doctor Strange', 'Logan', 'Desperate Housewives', 'Captain Marvel', 'Malcolm in the Middle', 'X-Men: First Class', 'Iron Man', 'Scandal', 'The Big Short', 'The Avengers', 'Spider-Man 3', 'Alien', 'Star Wars: Rebels', 'Bohemian Rhapsody', 'The Proposal', 'Star Wars: Episode I - The Phantom Menace', 'Cinderella', 'Spider-Man 2', 'White Collar', 'Glee', 'The Revenant', 'Single Drunk Female', 'American Dad!', 'Hidden Figures', '10 Things I Hate About You', 'The Lion King', 'Captain America: The First Avenger', 'American Crime Story', 'The Amazing Spider-Man 2', 'The Ice Age Adventures of Buck Wild', 'Cars', 'Black Swan', 'Coco', 'Miraculous: Tales of Ladybug & Cat Noir', 'Rogue One: A Star Wars Story', 'Last Man Standing', 'Zootopia', 'Sweet Home Alabama', 'Thor', 'The Falcon and the Winter Soldier', 'The Shape of Water', 'Angel', 'Burn Notice', 'Snowdrop', 'The Killing', 'Captain America: Civil War', 'Cheaper by the Dozen', 'Frozen', 'X-Men', 'Star Wars: Episode VII - The Force Awakens', "Ron's Gone Wrong", 'Independence Day', 'The Proud Family', 'The Sandlot', 'Boy Meets World', 'Avengers: Age of Ultron', "Romy and Michele's High School Reunion", 'Ratatouille', 'Guardians of the Galaxy Vol. 2', 'Gravity Falls', 'Beauty and the Beast', 'Pretty Woman', 'The Night House', 'Mayans M.C.', 'Revenge', 'The Incredibles', 'Three Billboards Outside Ebbing, Missouri', 'Star Wars: Episode III - Revenge of the Sith', 'The Wonder Years', 'Star Wars: Episode II - Attack of the Clones', 'The Help', 'Chucky', 'Black-ish', 'Alias', 'Star Wars: Episode V - The Empire Strikes Back', 'Solo: A Star Wars Story', 'Grantchester', 'Ford v Ferrari', 'Red Sparrow', 'Star Wars: Episode VI - Return of the Jedi', 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe', 'Mr Inbetween', 'Nomadland', 'Die Hard', 'She-Hulk', 'The Lion King', 'Soul', 'X-Men: Apocalypse', 'Pirates of the Caribbean: Dead Men Tell No Tales', 'Star Wars: The Bad Batch', 'Willow', 'Captain America: The Winter Soldier', 'Happy End ...

# %%
#create a similar search approach from users input
find_close_match = difflib.get_close_matches(movie_name, list_of_all_titles)
print(find_close_match)
# Out:
# ['Avengers: Endgame', 'Avengers: Infinity War', 'Avengers: Age of Ultron']

# %%
close_match = find_close_match[0]
print(close_match)
# Out:
# Avengers: Endgame

# %%
index_of_the_movie = dataset[dataset.title == close_match]["index"].values[0]
print(index_of_the_movie)
# Out:
# 28

# %%
#calculating similarity score
similarity_score = list(enumerate(similarity[index_of_the_movie]))
print(similarity_score)
# Out:
# [(0, 0.03786774488593453), (1, 0.01496895851768545), (2, 0.046152746597013676), (3, 0.03372380116741168), (4, 0.02014782105718865), (5, 0.017835841530001263), (6, 0.0), (7, 0.0), (8, 0.015032395448514216), (9, 0.021156052949071275), (10, 0.017638768347712486), (11, 0.05251514746710337), (12, 0.05725163205650377), (13, 0.04850333693726995), (14, 0.03320143319931056), (15, 0.08166176397689288), (16, 0.04452811703498612), (17, 0.018465883199775036), (18, 0.029977625513235778), (19, 0.09960840817802642), (20, 0.06172504625888927), (21, 0.019105007997584002), (22, 0.069215695612119), (23, 0.016857895282646643), (24, 0.019150743229827353), (25, 0.052092167907377016), (26, 0.02040818644489511), (27, 0.039531262044218696), (28, 1.0000000000000002), (29, 0.004749911757702377), (30, 0.04382044257045009), (31, 0.038829419090676665), (32, 0.04632599448528855), (33, 0.021772986700383915), (34, 0.005140464373239651), (35, 0.02218762153578466), (36, 0.0519430065709065), (37, 0.0), (38, 0.045296156782049485), (39, 0.04545902555121991), (40, 0.01854984810549913), (41, 0.02288263163627613), (42, 0.02119102535250965), (43, 0.0), (44, 0.05021112964498456), (45, 0.03669014657677226), (46, 0.021958864205168807), (47, 0.058751311784800184), (48, 0.06974320834035705), (49, 0.0), (50, 0.08417541152640963), (51, 0.06475836120733289), (52, 0.05873634928446535), (53, 0.020657102047431743), (54, 0.5429009674
, 0.09897672836590254), (7254, 0.09897672836590254), (7524, 0.0989408365146992), (7697, 0.09892483231459581), (510, 0.0986111086437444), (7835, 0.09856997418436805), (219, 0.09851816112125243), (5068, 0.09837594299595143), (2012, 0.0982587116562141), (5502, 0.09700823824845844), (5504, 0.09700823824845844), (5506, 0.09700823824845844), (7705, 0.09687107131507554), (7707, 0.09687107131507554), (7713, 0.09687107131507554), (7715, 0.0968 ...

# %%
print("Movie suggested for you: \n")
i = 1
for movie in sorted_similarity_movie:
    index = movie[0]
    title_index = dataset[dataset.index == index]['title'].values[0]
    if (i < 30):
        print(i, "", title_index)
        i+=1
# Out:
# Movie suggested for you:
#
# 1  Avengers: Endgame
# 2  Avengers: Infinity War
# 3  Captain America: The Winter Soldier
# 4  Captain America: Civil War
# 5  Avengers Assemble
# 6  The Avengers
# 7  Becoming
# 8  Red Tails
# 9  The Falcon and the Winter Soldier
# 10  Black-ish
# 11  Star Wars: Droids
# 12  NFL Monday Night Football
# 13  The Avengers: Earth's Mightiest Heroes
# 14  Avengers: Age of Ultron
# 15  Lego Star Wars: Droid Tales
# 16  Next Avengers: Heroes of Tomorrow
# 17  Avengers: United They Stand
# 18  The Mandalorian
# 19  The Simpsons
# 20  Limitless
# 21  WandaVision
# 22  Hawkeye
# 23  T.O.T.S.
# 24  The Mandalorian
# 25  The Mandalorian
# 26  9-1-1: Lone Star
# 27  Hawkeye
# 28  The Simpsons
# 29  Loki

# %% [markdown]
# ## combination of codes into one cell to become a movie recommendation

# %%
#Full code for the recommendation system
movie_name = input("disney movie apa yang ingin kamu tonton : ")
list_of_all_titles = dataset["title"].tolist()
find_close_match = difflib.get_close_matches(movie_name, list_of_all_titles)
close_match = find_close_match[0]
index_of_the_movie = dataset[dataset.title == close_match]["index"].values[0]
similarity_score = list(enumerate(similarity[index_of_the_movie]))
sorted_similarity_movie = sorted(similarity_score, key = lambda x:x[1], reverse = True)

print("Movies suggested for you : \n ")

i = 1
for movie in sorted_similarity_movie:
    index = movie[0]
    title_index = dataset[dataset.index == index]['title'].values[0]
    if (i < 30):
        print(i, "", title_index)
        i+=1
# Out:
# disney movie apa yang ingin kamu tonton : Avengers: Endgame
# Movies suggested for you :
#
# 1  Avengers: Endgame
# 2  Avengers: Infinity War
# 3  Captain America: The Winter Soldier
# 4  Captain America: Civil War
# 5  Avengers Assemble
# 6  The Avengers
# 7  Becoming
# 8  Red Tails
# 9  The Falcon and the Winter Soldier
# 10  Black-ish
# 11  Star Wars: Droids
# 12  NFL Monday Night Football
# 13  The Avengers: Earth's Mightiest Heroes
# 14  Avengers: Age of Ultron
# 15  Lego Star Wars: Droid Tales
# 16  Next Avengers: Heroes of Tomorrow
# 17  Avengers: United They Stand
# 18  The Mandalorian
# 19  The Simpsons
# 20  Limitless
# 21  WandaVision
# 22  Hawkeye
# 23  T.O.T.S.
# 24  The Mandalorian
# 25  The Mandalorian
# 26  9-1-1: Lone Star
# 27  Hawkeye
# 28  The Simpsons
# 29  Loki

# %% [markdown]
# ## Conclusion

# %% [markdown]
# This film recommendation system functions to search for films related to the film that the user wants to search for, such as the relationship between the title, genre, year of release, and the director in the details of the film. For example, the film Avengers: Endgame has a connection with Avengers: Infinity War and has links with other similar films. so we as users will find other recommended movies after we watch the movie we want
